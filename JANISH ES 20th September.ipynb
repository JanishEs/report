# %%
"
import numpy as np 
import pandas as pd   
labels=['a','b','c','d']  
data=[10,20,30,40]  
arr=np.array(data)  
d={'a':10,'b':20,'c':30,'d':40}  
data=[23,45,67,34,89,90]
#creating series with list 
pd.Series(data)  
#creatinf series with list and index values 
pd.Series(data, index=labels) #or 
pd.Series(data,labels)  
#creating series in  line filling data and index values  
data=pd.Series([23,34,45,56], ['a','b','c','d'])  
#creating list with an array 
pd.Series(arr) #or 
pd.Series(arr, labels)  
#creating dictionary using zip() 
my_dict=dict(zip(data,labels))  
#creating list with dictionary 
pd.Series(d)  
ser1 = pd.Series([1,2,3,4],index = ['USA','India','Italy', 'China'])                                   
ser2 = pd.Series([1,2,5,4],index = ['USA', 'Germany','India', 'China'])    
#accessing values using indexing and index names                                  
ser1['Italy']
ser1[0:3] 
ser1[3] 
ser1 + ser2    
from numpy.random import randn 
randn(5,4) 
#creating dataframe using random with index values and column names 
df = pd.DataFrame(randn(5,4),index=['A', 'B', 'C', 'D', 'E'],columns=['W', 'X', 'Y', 'Z']) 
#checking for type od dataframe and series in it 
type(df) 
type(df['W'])  
#applying conditional slicing on dataframe 
df>0 
df[df>0]#dataframe where values are greater than 0 
df[df['W']>0]#dataframe where values in column 'W' are greater than 0 
df[df['W']>0]['Y']#column y of dataframe where values in column 'W' are greater than 0 
df[df['W']>0][['Y','X']]#column X and y of dataframe where values in column 'W' are greater than 0 
df[(df['W']>0) & (df['Y'] > 1)]# For two conditions you can use | and & with parenthesis: 
""" More Index Details# # Let's discuss some more features of indexing, 
including resetting the index or setting it something else. We'll also talk about index hierarchy! """
#reset index values back to 0 1 2.... 
df.reset_index() 
#adding a new column in data frame 
newind = ['P','O','W','Y'] 
df['St'] = newind 
#setting a column values as index 
df.set_index('St')  
df.set_index('St',inplace=True) 


df.hist()

# %%
import numpy as np 
import pandas as pd   
labels=['a','b','c','d']  
data=[10,20,30,40]  
arr=np.array(data)  
d={'a':10,'b':20,'c':30,'d':40}  
data=[23,45,67,34,89,90]

# %%
#creating series with list 
pd.Series(data)
# Out:
# 0    23
# 1    45
# 2    67
# 3    34
# 4    89
# 5    90
# dtype: int64

# %%
#creatinf series with list and index values 
labels=['a','b','c','d','e','f']  
pd.Series(data,index=labels) #or 
pd.Series(data,labels)
# Out:
# a    23
# b    34
# c    45
# d    56
# dtype: int64

# %%
#creating series in  line filling data and index values  
data=pd.Series([23,34,45,56], ['a','b','c','d']) 
data
# Out:
# a    23
# b    34
# c    45
# d    56
# dtype: int64

# %%
 
#creating list with an array 
pd.Series(arr) #or 
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
#creating list with dictionary 
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4],index = ['USA','India','Italy', 'China'])                                   
ser2 = pd.Series([1,2,5,4],index = ['USA', 'Germany','India', 'China']) 
#accessing values using indexing and index names                                  
ser1['Italy']
ser1[0:3] 
ser1[3] 
ser1 + ser2
# Out:
# China      8.0
# Germany    NaN
# India      7.0
# Italy      NaN
# USA        2.0
# dtype: float64

# %%
from numpy.random import randn 
randn(5,4)
# Out:
# array([[ 0.2296228 , -0.27851375,  0.35618111, -1.07939739],
#        [-0.92459724, -0.3976737 ,  1.34146095,  1.05670716],
#        [ 2.70888582, -0.63004641,  0.89065637,  1.38207286],
#        [ 0.29578558, -0.95094811,  1.19293595,  0.97287354],
#        [-0.88113449, -0.65752123,  1.50455472,  0.77634121]])

# %%
#creating dataframe using random with index values and column names 
df = pd.DataFrame(randn(5,4),index=['A', 'B', 'C', 'D', 'E'],columns=['W', 'X', 'Y', 'Z']) 
df
# Out:
#           W         X         Y         Z
# A  1.036131  0.428054 -1.479939 -0.695373
# B  0.560385  1.315627 -1.290694  0.129156
# C -0.381135 -0.066581  0.021301 -0.896247
# D  0.673473  1.689184 -0.926983  1.294409
# E  1.932791 -1.646862  0.838290 -1.139634

# %%
#checking for type od dataframe and series in it 
type(df) 
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
#applying conditional slicing on dataframe 
df>0 
df[df>0]#dataframe where values are greater than 0 
df[df['W']>0]#dataframe where values in column 'W' are greater than 0 
df[df['W']>0]['Y']#column y of dataframe where values in column 'W' are greater than 0 
df[df['W']>0][['Y','X']]#column X and y of dataframe where values in column 'W' are greater than 0 
df[(df['W']>0) & (df['Y'] > 1)]# For two conditions you can use | and & with parenthesis:
# Out:
# Empty DataFrame
# Columns: [W, X, Y, Z]
# Index: []

# %%
#reset index values back to 0 1 2.... 
df.reset_index()#reset index values back to 0 1 2.... 
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  1.036131  0.428054 -1.479939 -0.695373
# 1     B  0.560385  1.315627 -1.290694  0.129156
# 2     C -0.381135 -0.066581  0.021301 -0.896247
# 3     D  0.673473  1.689184 -0.926983  1.294409
# 4     E  1.932791 -1.646862  0.838290 -1.139634

# %%
#adding a new column in data frame 
newind = ['P','O','W','Y','S'] 
df['St'] = newind 
df
# Out:
#           W         X         Y         Z St
# A  1.036131  0.428054 -1.479939 -0.695373  P
# B  0.560385  1.315627 -1.290694  0.129156  O
# C -0.381135 -0.066581  0.021301 -0.896247  W
# D  0.673473  1.689184 -0.926983  1.294409  Y
# E  1.932791 -1.646862  0.838290 -1.139634  S

# %%
newind = ['P','O','W','Y','S'] 
df['St'] = newind 
#setting a column values as index 
df.set_index('St')
df.set_index('St',inplace=True)   

df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f34f5c54d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34f5c54910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f34f5be0310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f34f5b95990>]],
#       dtype=object)
