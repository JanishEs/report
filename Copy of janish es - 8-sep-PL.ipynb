# %%
class bill():
  def __init__(self, amount,item,quantity, cust_name):
    self.amount=amount
    self.item=item
    self.quantity=quantity
    self.cust_name=cust_name

  def bill_print(self):
    print(self.cust_name)
    x=(self.amount) * (self.quantity)
    print("Item\t:{0}\namount\t:{1}\nquantity:{2}\n TOTAL\t:{3} ".format(self.item, self.amount, self.quantity,x) )

# %%
bill1=bill(12,"carrot", 2,"Pratibha")

# %%
bill1.bill_print()
# Out:
# Pratibha
# Item	:carrot
# amount	:12
# quantity:2
#  TOTAL	:24

# %% [markdown]
# Execute the above code.
# Create a child class of bill.
# child 1 class for creating bills of vegetables
# child 2 class for creating bills of fruits
# child 3 class for creating bills of stationary
# in each class provide the list of items which a user can pick to buy, and amount be displayed to the user for each item. Use dictionary to do so like
#
# ```
# veg={"carrot" : 12, "capsicum" : 23, "potato" : 10, "onion" :10}
# ```

# %%
class bill():
  def _init_(self, amount,item,quantity, cust_name):

  
    self.amount=amount
    self.item=item
    self.quantity=quantity
    self.cust_name=cust_name

  def bill_print(self):
    print(self.cust_name)
    x=(self.amount) * (self.quantity)
    print("Item\t:{0}\namount\t:{1}\nquantity:{2}\n TOTAL\t:{3} ".format(self.item, self.amount, self.quantity,x) )
class print_bill(veg,fruits,stationary):
    def print_bill():
      def _init_(self):
        pass
      def print_bill(self):
        
        amount_veg=self.bill_veg


class veg(bill):
  def dis_veg():
    d={"item":"cost","carrot":12,"potato":10,"capsicum":23}
    print("Vegetables avaliable")
    for i in d.items():
      print(i)
class fruits(bill):
  def dis_fruits():
    d={"item":"cost","apple":12,"banana":10,"grapes":23}
    print("Fruits avaliable")
    for j in d.items():
      print(j)
class fruits(bill):
  def dis_stationary():
    d={"item":"cost","book":12,"pen":10,"eraser":3}
    print("Stationary avaliable")
    for l in d.items():
      print(l)
def vege():
  d_vege={"item":"cost","carrot":12,"potato":10,"capsicum":23}
  d_pick={1:"carrot",2:"potato",3:"capsicum"}
  def bill_veg():
    print("Choose from the list")
    d_pick={1:"carrot",2:"potato",3:"capsicum"}
    for i in d_pick.items():
      print(i)
      x=int(input("Enter your choice"))
      y=int(input("Enter the quantity"))
      if x==1:
        amount=d_vege["carrot"]*y 
      elif x==2:
        amount=d_vege["potato"]*y 
      else:
        amount=d_vege["capsicum"]*y 
        return amount
def fruits():
  d_fruits={"item":"cost","apple":12,"banana":10,"grapes":23}
  d_pick={1:"apple",2:"banana",3:"grapes"}
  def bill_fruits():
    print("Choose from the list")
    d_pick={1:"apple",2:"banana",3:"grapes"}
    for i in d_pick.items():
      print(i)
      x=int(input("Enter your choice"))
      y=int(input("Enter the quantity"))
      if x==1:
        amount=d_fruits["apple"]*y 
      elif x==2:
        amount=d_fruits["banana"]*y 
      else:
        amount=d_fruits["grapes"]*y 
        return amount
def stationaries():
  d_stationaries={"item":"cost","book":12,"pen":10,"eraser":3}
  d_pick={1:"book",2:"pen",3:"eraser"}
  def bill_stationaries():
    print("Choose from the list")
    d_pick={1:"book",2:"pen",3:"eraser"}
    for i in d_pick.items():
      print(i)
      x=int(input("Enter your choice"))
      y=int(input("Enter the quantity"))
      if x==1:
        amount=d_stationaries["book"]*y 
      elif x==2:
        amount=d_stationaries["pen"]*y 
      else:
        amount=d_stationaries["eraser"]*y 
        return amount
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1a42415f6533> in <module>()
#      12     x=(self.amount) * (self.quantity)
#      13     print("Item\t:{0}\namount\t:{1}\nquantity:{2}\n TOTAL\t:{3} ".format(self.item, self.amount, self.quantity,x) )
# ---> 14 class print_bill(veg,fruits,stationary):
#      15     def print_bill():
#      16       def _init_(self):
#
# NameError: name 'veg' is not defined

# %%
#write a function in the parent class to calculate the total bill of a customer (sum of bill from veg, fruits, stationary)
class bill():
  def _init_(self, amount,item,quantity, cust_name):

  
    self.amount=amount
    self.item=item
    self.quantity=quantity
    self.cust_name=cust_name

  def bill_print(self):
    print(self.cust_name)
    x=(self.amount) * (self.quantity)
    print("Item\t:{0}\namount\t:{1}\nquantity:{2}\n TOTAL\t:{3} ".format(self.item, self.amount, self.quantity,x) )

  def print_bill(self):
    amount_veg=self.bill_veg()
    amount_fruit=self.bill_fruit()
    amount_stationary=self.bill_stationary()
    total=amount_veg+amount_fruit+amount_stationary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-c727d01aa3aa> in <module>()
#       1 #write a function in the parent class to calculate the total bill of a customer (sum of bill from veg, fruits, stationary)
# ----> 2 class bill():
#       3   def _init_(self, amount,item,quantity, cust_name):
#       4
#       5
#
# <ipython-input-4-c727d01aa3aa> in bill()
#      21
#      22   bills=bill()
# ---> 23   bills.print_bill()
#      24
#
# <ipython-input-3-8a23caeb6773> in print_bill(self)
#      15
#      16   def print_bill(self):
# ---> 17     amount_veg=self.bill_veg()
#      18     amount_fruit=self.bill_fruit()
#      19     amount_stationary=self.bill_stationary()
#
# AttributeError: 'bill' object has no attribute 'bill_veg'

# %%
# in the parent class write a method/function to print the bill as a file. 
#Save the total bill in a text file named on the cust_name. 
#Display this file when asked to print total bill
def total_bill(name,amount):
  l=[]
  for i in range(10):
    l.append(item)
    s=self.name
    s_f=s+"."+"txt"
  with open(s_f,"w") as f:
    f.writeline(["item1:,","item2:"])
  f=fopen()

# %% [markdown]
# Lets practice on creating functions....

# %%
#Create a function which will ask the user to input a word in English. Make sure the user entered a valid word. 
#Convert the word from English like this:- 
#Input : SUKUN Output : UKUNSPK [(2nd alphabet to end) + 1st alphabet + ‘PK’]. Display the translated result.
def fun():
  s=input("Enter a word in English")
  converted=s[1:]+s[0]+"PK"
  return print(converted)
fun()
# Out:
# Enter a word in Englishdfggh
# fgghdPK

# %%
#create a function which will take a string as input and display an input string like this:- 
#input = 'computer' 
#output as follows:-
#r computer 
#er compute 
#ter comput 
#uter compu 
#puter comp 
#mputer com 
#omputer co 
#computer c
s="computer"
def pattern():
  for i in range(8):
   print(s[8-i-1:]+" "+s[:8-i])
pattern()
# Out:
# r computer
# er compute
# ter comput
# uter compu
# puter comp
# mputer com
# omputer co
# computer c

# %%
#wrute a function to read a list of words and return the length of the longest one.
def find_longest_word(words_list):
    word_len = []
    for n in words_list:
        word_len.append((len(n), n))
    word_len.sort()
    return word_len[-1][0], word_len[-1][1]
result = find_longest_word(["Python", "Excitement", "Back"])
print("\nLongest word: ",result[1])
print("Length of the longest word: ",result[0])
# Out:
# Longest word:  Excitement
# Length of the longest word:  10

# %%
"""Define a function scrabble_score that takes a string word as input  and returns the equivalent scrabble score for that word. Assume your input is only one word  containing no spaces or punctuation.  As mentioned, no need to worry about score multipliers! 
For example: the word "Helix" would score 15points due to the sum of the 
letters: 4 + 1 + 1 + 1 + 8. 
score = {"a": 1, "c": 3, "b": 3, "e": 1, "d": 2, "g": 2, "f": 4, "i": 1, "h": 4, "k": 5, "j": 8, "m": 3, "l": 1, "o": 1, "n": 1, "q": 10, "p": 3, "s": 1,"r": 1, "u": 1, "t": 1, "w": 4, "v": 4, "y": 4,"x": 8, "z": 10}
"""
score = {"a": 1, "c": 3, "b": 3, "e": 1, "d": 2, "g": 2, "f": 4, "i": 1, "h": 4, "k": 5, "j": 8, "m": 3, "l": 1, "o": 1, "n": 1, "q": 10, "p": 3, "s": 1,"r": 1, "u": 1, "t": 1, "w": 4, "v": 4, "y": 4,"x": 8, "z":  10}
def scrabble_score(word):
  word=word.lower()
  total=0
  for letter in word:
      total+=score[letter]
  return total
print(scrabble_score("wonder"))
# Out:
# 10
